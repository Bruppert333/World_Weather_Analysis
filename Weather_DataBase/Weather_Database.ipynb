# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 742

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | aklavik
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | krasnoselkup
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | te anau
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | kameoka
# Processing Record 21 of Set 1 | shahkot
# Processing Record 22 of Set 1 | gambo
# Processing Record 23 of Set 1 | bagdarin
# Processing Record 24 of Set 1 | tilichiki
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | nago
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | cockburn town
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | praia da vitoria
# Processing Record 36 of Set 1 | beringovskiy
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | narsaq
# Processing Record 40 of Set 1 | haines junction
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | barentu
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | tangerang
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | port-cartier
# Processing Record 47 of Set 1 | el faiyum
# City not found. Skipping...
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | koumac
# Processing Record 1 of Set 2 | charlestown
# Processing Record 2 of Set 2 | hualmay
# Processing Record 3 of Set 2 | matagami
# Processing Record 4 of Set 2 | poum
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | seoul
# Processing Record 9 of Set 2 | arrecife
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 12 of Set 2 | yumen
# Processing Record 13 of Set 2 | coihaique
# Processing Record 14 of Set 2 | sumbe
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | trairi
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | polunochnoye
# Processing Record 19 of Set 2 | sorong
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | coffs harbour
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | salalah
# Processing Record 25 of Set 2 | olafsvik
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | lorengau
# Processing Record 28 of Set 2 | norman wells
# Processing Record 29 of Set 2 | constitucion
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | dakar
# Processing Record 32 of Set 2 | aykhal
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | sao filipe
# Processing Record 35 of Set 2 | tomigusuku
# Processing Record 36 of Set 2 | zhangjiakou
# Processing Record 37 of Set 2 | batagay
# Processing Record 38 of Set 2 | sonoita
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | fuxin
# Processing Record 41 of Set 2 | rairangpur
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | hauknes
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | aloleng
# Processing Record 46 of Set 2 | davila
# Processing Record 47 of Set 2 | batemans bay
# Processing Record 48 of Set 2 | jamame
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | ust-tsilma
# Processing Record 1 of Set 3 | tigil
# Processing Record 2 of Set 3 | vila velha
# Processing Record 3 of Set 3 | midland
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | motala
# Processing Record 6 of Set 3 | ciudad bolivar
# Processing Record 7 of Set 3 | goderich
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | sioux lookout
# Processing Record 10 of Set 3 | kutum
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | carutapera
# Processing Record 16 of Set 3 | conceicao da barra
# Processing Record 17 of Set 3 | tarsus
# Processing Record 18 of Set 3 | yuanping
# Processing Record 19 of Set 3 | pervoye maya
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | wilmington
# Processing Record 22 of Set 3 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 3 | hirado
# Processing Record 24 of Set 3 | yerbogachen
# Processing Record 25 of Set 3 | chernyshevskiy
# Processing Record 26 of Set 3 | umm bab
# Processing Record 27 of Set 3 | westport
# Processing Record 28 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 3 | tuatapere
# Processing Record 30 of Set 3 | constantine
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | walvis bay
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | kavaratti
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | salinas
# Processing Record 40 of Set 3 | nuuk
# Processing Record 41 of Set 3 | omboue
# Processing Record 42 of Set 3 | karlovac
# Processing Record 43 of Set 3 | batagay-alyta
# Processing Record 44 of Set 3 | jinka
# Processing Record 45 of Set 3 | zabid
# Processing Record 46 of Set 3 | sechura
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 3 | vardo
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | fort nelson
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | bengkulu
# Processing Record 4 of Set 4 | gigmoto
# Processing Record 5 of Set 4 | vagay
# Processing Record 6 of Set 4 | opotiki
# Processing Record 7 of Set 4 | naryan-mar
# Processing Record 8 of Set 4 | alice springs
# Processing Record 9 of Set 4 | jalu
# Processing Record 10 of Set 4 | cuauhtemoc
# Processing Record 11 of Set 4 | kamenka
# Processing Record 12 of Set 4 | leningradskiy
# Processing Record 13 of Set 4 | nyzy
# Processing Record 14 of Set 4 | hastings
# Processing Record 15 of Set 4 | prince rupert
# Processing Record 16 of Set 4 | rundu
# Processing Record 17 of Set 4 | rantepao
# Processing Record 18 of Set 4 | inirida
# Processing Record 19 of Set 4 | biak
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | saint-augustin
# Processing Record 24 of Set 4 | ritchie
# Processing Record 25 of Set 4 | dawlatabad
# Processing Record 26 of Set 4 | dingle
# Processing Record 27 of Set 4 | yarada
# Processing Record 28 of Set 4 | baoying
# Processing Record 29 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 4 | nikolskoye
# Processing Record 31 of Set 4 | geraldton
# Processing Record 32 of Set 4 | tabuk
# Processing Record 33 of Set 4 | kruisfontein
# Processing Record 34 of Set 4 | clyde river
# Processing Record 35 of Set 4 | makokou
# Processing Record 36 of Set 4 | naron
# Processing Record 37 of Set 4 | iqaluit
# Processing Record 38 of Set 4 | araouane
# Processing Record 39 of Set 4 | muborak
# Processing Record 40 of Set 4 | lebowakgomo
# Processing Record 41 of Set 4 | najran
# Processing Record 42 of Set 4 | cayenne
# Processing Record 43 of Set 4 | loandjili
# Processing Record 44 of Set 4 | panguna
# Processing Record 45 of Set 4 | pinega
# Processing Record 46 of Set 4 | kloulklubed
# Processing Record 47 of Set 4 | mayumba
# Processing Record 48 of Set 4 | alta floresta
# Processing Record 49 of Set 4 | kysyl-syr
# Processing Record 50 of Set 4 | korla
# Processing Record 1 of Set 5 | evensk
# Processing Record 2 of Set 5 | akureyri
# Processing Record 3 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 5 | vredendal
# Processing Record 5 of Set 5 | oranzherei
# Processing Record 6 of Set 5 | mehamn
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | mackay
# Processing Record 10 of Set 5 | qasigiannguit
# Processing Record 11 of Set 5 | kavieng
# Processing Record 12 of Set 5 | girau do ponciano
# Processing Record 13 of Set 5 | lalibela
# Processing Record 14 of Set 5 | dole
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | quatre cocos
# Processing Record 17 of Set 5 | ville-marie
# Processing Record 18 of Set 5 | hay river
# Processing Record 19 of Set 5 | praia
# Processing Record 20 of Set 5 | taltal
# Processing Record 21 of Set 5 | izacic
# Processing Record 22 of Set 5 | san carlos de bariloche
# Processing Record 23 of Set 5 | sukumo
# Processing Record 24 of Set 5 | umba
# Processing Record 25 of Set 5 | haimen
# Processing Record 26 of Set 5 | merauke
# Processing Record 27 of Set 5 | beira
# Processing Record 28 of Set 5 | atambua
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | puerto madryn
# Processing Record 31 of Set 5 | faya
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | delemont
# Processing Record 34 of Set 5 | rajaldesar
# Processing Record 35 of Set 5 | kahului
# Processing Record 36 of Set 5 | hilo
# Processing Record 37 of Set 5 | bafia
# Processing Record 38 of Set 5 | tezu
# Processing Record 39 of Set 5 | lerwick
# Processing Record 40 of Set 5 | ossora
# Processing Record 41 of Set 5 | ternate
# Processing Record 42 of Set 5 | udomlya
# Processing Record 43 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 44 of Set 5 | tejupilco
# City not found. Skipping...
# Processing Record 45 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 5 | bantry
# Processing Record 47 of Set 5 | lasa
# Processing Record 48 of Set 5 | la ronge
# Processing Record 49 of Set 5 | marstal
# Processing Record 50 of Set 5 | georgetown
# Processing Record 1 of Set 6 | pangnirtung
# Processing Record 2 of Set 6 | meulaboh
# Processing Record 3 of Set 6 | quang ngai
# Processing Record 4 of Set 6 | wanganui
# Processing Record 5 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 6 | margate
# Processing Record 7 of Set 6 | cap malheureux
# Processing Record 8 of Set 6 | kalaleh
# Processing Record 9 of Set 6 | riyadh
# Processing Record 10 of Set 6 | honiara
# Processing Record 11 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 12 of Set 6 | springdale
# Processing Record 13 of Set 6 | fayaoue
# Processing Record 14 of Set 6 | carmen
# Processing Record 15 of Set 6 | oranjestad
# Processing Record 16 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 6 | nouadhibou
# Processing Record 18 of Set 6 | porto novo
# Processing Record 19 of Set 6 | bac lieu
# Processing Record 20 of Set 6 | kodinsk
# Processing Record 21 of Set 6 | guarapari
# Processing Record 22 of Set 6 | janakpur road
# City not found. Skipping...
# Processing Record 23 of Set 6 | taoudenni
# Processing Record 24 of Set 6 | humaita
# Processing Record 25 of Set 6 | amilly
# Processing Record 26 of Set 6 | port lincoln
# Processing Record 27 of Set 6 | jiuquan
# Processing Record 28 of Set 6 | port hedland
# Processing Record 29 of Set 6 | karratha
# Processing Record 30 of Set 6 | nanortalik
# Processing Record 31 of Set 6 | camocim
# Processing Record 32 of Set 6 | bontang
# Processing Record 33 of Set 6 | kandrian
# Processing Record 34 of Set 6 | matay
# Processing Record 35 of Set 6 | paita
# Processing Record 36 of Set 6 | volot
# Processing Record 37 of Set 6 | baherden
# Processing Record 38 of Set 6 | husavik
# Processing Record 39 of Set 6 | rawson
# Processing Record 40 of Set 6 | grass valley
# Processing Record 41 of Set 6 | cherskiy
# Processing Record 42 of Set 6 | panjwin
# City not found. Skipping...
# Processing Record 43 of Set 6 | linqing
# Processing Record 44 of Set 6 | mattru
# Processing Record 45 of Set 6 | deputatskiy
# Processing Record 46 of Set 6 | saint-philippe
# Processing Record 47 of Set 6 | matiri
# Processing Record 48 of Set 6 | plavinas
# Processing Record 49 of Set 6 | chumphon
# Processing Record 50 of Set 6 | ulaangom
# Processing Record 1 of Set 7 | sidi ali
# Processing Record 2 of Set 7 | shiyan
# Processing Record 3 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 4 of Set 7 | chadiza
# Processing Record 5 of Set 7 | kropotkin
# Processing Record 6 of Set 7 | jiujiang
# Processing Record 7 of Set 7 | townsville
# Processing Record 8 of Set 7 | lagoa
# Processing Record 9 of Set 7 | les cayes
# Processing Record 10 of Set 7 | koutiala
# Processing Record 11 of Set 7 | pangai
# Processing Record 12 of Set 7 | mgandu
# Processing Record 13 of Set 7 | barranquilla
# Processing Record 14 of Set 7 | norden
# Processing Record 15 of Set 7 | waipawa
# Processing Record 16 of Set 7 | bageshwar
# Processing Record 17 of Set 7 | oranjemund
# Processing Record 18 of Set 7 | le port
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | hithadhoo
# Processing Record 21 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 7 | thinadhoo
# Processing Record 23 of Set 7 | saint-pierre
# Processing Record 24 of Set 7 | birjand
# Processing Record 25 of Set 7 | talcahuano
# Processing Record 26 of Set 7 | sarh
# Processing Record 27 of Set 7 | perustica
# City not found. Skipping...
# Processing Record 28 of Set 7 | makakilo city
# Processing Record 29 of Set 7 | pudozh
# Processing Record 30 of Set 7 | mukhen
# Processing Record 31 of Set 7 | kholm
# Processing Record 32 of Set 7 | necochea
# Processing Record 33 of Set 7 | okhotsk
# Processing Record 34 of Set 7 | daru
# Processing Record 35 of Set 7 | magaria
# Processing Record 36 of Set 7 | hami
# Processing Record 37 of Set 7 | auki
# Processing Record 38 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 7 | kautokeino
# Processing Record 40 of Set 7 | madimba
# Processing Record 41 of Set 7 | uppsala
# Processing Record 42 of Set 7 | itarema
# Processing Record 43 of Set 7 | port blair
# Processing Record 44 of Set 7 | praxedis guerrero
# Processing Record 45 of Set 7 | namibe
# Processing Record 46 of Set 7 | jaen
# Processing Record 47 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 7 | fatehabad
# Processing Record 49 of Set 7 | airai
# Processing Record 50 of Set 7 | cidreira
# Processing Record 1 of Set 8 | magadan
# Processing Record 2 of Set 8 | lavrentiya
# Processing Record 3 of Set 8 | ancud
# Processing Record 4 of Set 8 | kinlochleven
# Processing Record 5 of Set 8 | san quintin
# Processing Record 6 of Set 8 | cabedelo
# Processing Record 7 of Set 8 | timmins
# Processing Record 8 of Set 8 | ulagan
# Processing Record 9 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 8 | labuhan
# Processing Record 11 of Set 8 | bambanglipuro
# Processing Record 12 of Set 8 | lamu
# Processing Record 13 of Set 8 | kapoeta
# Processing Record 14 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 8 | impfondo
# Processing Record 16 of Set 8 | obihiro
# Processing Record 17 of Set 8 | vila franca do campo
# Processing Record 18 of Set 8 | rognan
# Processing Record 19 of Set 8 | sept-iles
# Processing Record 20 of Set 8 | senanga
# Processing Record 21 of Set 8 | sinnamary
# Processing Record 22 of Set 8 | longyearbyen
# Processing Record 23 of Set 8 | berlevag
# Processing Record 24 of Set 8 | bogorodskoye
# Processing Record 25 of Set 8 | pozo colorado
# Processing Record 26 of Set 8 | leh
# Processing Record 27 of Set 8 | dunedin
# Processing Record 28 of Set 8 | la asuncion
# Processing Record 29 of Set 8 | esna
# Processing Record 30 of Set 8 | jacqueville
# Processing Record 31 of Set 8 | tra vinh
# Processing Record 32 of Set 8 | plainview
# Processing Record 33 of Set 8 | purranque
# Processing Record 34 of Set 8 | takoradi
# Processing Record 35 of Set 8 | vernon
# Processing Record 36 of Set 8 | kaitangata
# Processing Record 37 of Set 8 | nakhon phanom
# Processing Record 38 of Set 8 | isangel
# Processing Record 39 of Set 8 | ipixuna
# Processing Record 40 of Set 8 | yoichi
# Processing Record 41 of Set 8 | beruwala
# Processing Record 42 of Set 8 | flinders
# Processing Record 43 of Set 8 | kikinda
# Processing Record 44 of Set 8 | manono
# Processing Record 45 of Set 8 | samarai
# Processing Record 46 of Set 8 | morti
# City not found. Skipping...
# Processing Record 47 of Set 8 | fremont
# Processing Record 48 of Set 8 | cabo san lucas
# Processing Record 49 of Set 8 | raahe
# Processing Record 50 of Set 8 | moroni
# Processing Record 1 of Set 9 | holoby
# Processing Record 2 of Set 9 | port keats
# Processing Record 3 of Set 9 | fershampenuaz
# Processing Record 4 of Set 9 | cassilandia
# Processing Record 5 of Set 9 | changji
# Processing Record 6 of Set 9 | mount isa
# Processing Record 7 of Set 9 | port hardy
# Processing Record 8 of Set 9 | ventspils
# Processing Record 9 of Set 9 | portland
# Processing Record 10 of Set 9 | havoysund
# Processing Record 11 of Set 9 | karakol
# Processing Record 12 of Set 9 | mandalgovi
# Processing Record 13 of Set 9 | liverpool
# Processing Record 14 of Set 9 | palmer
# Processing Record 15 of Set 9 | sao joao da barra
# Processing Record 16 of Set 9 | college
# Processing Record 17 of Set 9 | shu
# Processing Record 18 of Set 9 | rio grande
# Processing Record 19 of Set 9 | diamantino
# Processing Record 20 of Set 9 | hamilton
# Processing Record 21 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 22 of Set 9 | maisuru
# City not found. Skipping...
# Processing Record 23 of Set 9 | mercedes
# Processing Record 24 of Set 9 | jackson
# Processing Record 25 of Set 9 | ouallam
# Processing Record 26 of Set 9 | caravelas
# Processing Record 27 of Set 9 | hauterive
# Processing Record 28 of Set 9 | chandler
# Processing Record 29 of Set 9 | sur
# Processing Record 30 of Set 9 | codrington
# Processing Record 31 of Set 9 | baturaja
# Processing Record 32 of Set 9 | kansanshi
# Processing Record 33 of Set 9 | ekhabi
# Processing Record 34 of Set 9 | pasni
# Processing Record 35 of Set 9 | xuddur
# Processing Record 36 of Set 9 | allada
# Processing Record 37 of Set 9 | dutse
# Processing Record 38 of Set 9 | nador
# Processing Record 39 of Set 9 | marrakesh
# Processing Record 40 of Set 9 | duz
# City not found. Skipping...
# Processing Record 41 of Set 9 | treinta y tres
# Processing Record 42 of Set 9 | belle fourche
# Processing Record 43 of Set 9 | kudat
# Processing Record 44 of Set 9 | iskilip
# Processing Record 45 of Set 9 | angol
# Processing Record 46 of Set 9 | beloha
# Processing Record 47 of Set 9 | bezhetsk
# Processing Record 48 of Set 9 | torquay
# Processing Record 49 of Set 9 | devils lake
# Processing Record 50 of Set 9 | inhambane
# Processing Record 1 of Set 10 | kaseda
# Processing Record 2 of Set 10 | vao
# Processing Record 3 of Set 10 | havelock
# Processing Record 4 of Set 10 | port-gentil
# Processing Record 5 of Set 10 | ostrovnoy
# Processing Record 6 of Set 10 | gomel
# Processing Record 7 of Set 10 | vredefort
# Processing Record 8 of Set 10 | wamba
# Processing Record 9 of Set 10 | ghanzi
# Processing Record 10 of Set 10 | agadez
# Processing Record 11 of Set 10 | juegang
# Processing Record 12 of Set 10 | totness
# Processing Record 13 of Set 10 | san cristobal
# Processing Record 14 of Set 10 | sisimiut
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | moorhead
# Processing Record 17 of Set 10 | panjab
# Processing Record 18 of Set 10 | north bend
# Processing Record 19 of Set 10 | copiapo
# Processing Record 20 of Set 10 | alexandria
# Processing Record 21 of Set 10 | kieta
# Processing Record 22 of Set 10 | diego de almagro
# Processing Record 23 of Set 10 | talgar
# Processing Record 24 of Set 10 | paramithia
# City not found. Skipping...
# Processing Record 25 of Set 10 | mabaruma
# Processing Record 26 of Set 10 | ostashkov
# Processing Record 27 of Set 10 | plettenberg bay
# Processing Record 28 of Set 10 | santo tomas
# Processing Record 29 of Set 10 | cerrito
# Processing Record 30 of Set 10 | paamiut
# Processing Record 31 of Set 10 | atascadero
# Processing Record 32 of Set 10 | catamarca
# Processing Record 33 of Set 10 | sakiai
# Processing Record 34 of Set 10 | kibaya
# Processing Record 35 of Set 10 | half moon bay
# Processing Record 36 of Set 10 | kirakira
# Processing Record 37 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 10 | roma
# Processing Record 39 of Set 10 | formosa
# Processing Record 40 of Set 10 | itaituba
# Processing Record 41 of Set 10 | laguna
# Processing Record 42 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 10 | horsham
# Processing Record 44 of Set 10 | rocha
# Processing Record 45 of Set 10 | ambilobe
# Processing Record 46 of Set 10 | anadyr
# Processing Record 47 of Set 10 | vitina
# Processing Record 48 of Set 10 | male
# Processing Record 49 of Set 10 | keuruu
# Processing Record 50 of Set 10 | kungurtug
# Processing Record 1 of Set 11 | sorland
# Processing Record 2 of Set 11 | hammerfest
# Processing Record 3 of Set 11 | huarmey
# Processing Record 4 of Set 11 | mlimba
# Processing Record 5 of Set 11 | havre-saint-pierre
# Processing Record 6 of Set 11 | tarauaca
# Processing Record 7 of Set 11 | newport
# Processing Record 8 of Set 11 | koungheul
# Processing Record 9 of Set 11 | lucapa
# Processing Record 10 of Set 11 | shelburne
# Processing Record 11 of Set 11 | san antonio
# Processing Record 12 of Set 11 | bull savanna
# Processing Record 13 of Set 11 | bereda
# Processing Record 14 of Set 11 | grindavik
# Processing Record 15 of Set 11 | saint-georges
# Processing Record 16 of Set 11 | pevek
# Processing Record 17 of Set 11 | ahvaz
# Processing Record 18 of Set 11 | progreso
# Processing Record 19 of Set 11 | touros
# Processing Record 20 of Set 11 | genhe
# Processing Record 21 of Set 11 | yei
# Processing Record 22 of Set 11 | ulma
# Processing Record 23 of Set 11 | ixtapa
# Processing Record 24 of Set 11 | zhigansk
# Processing Record 25 of Set 11 | hohhot
# Processing Record 26 of Set 11 | calvia
# Processing Record 27 of Set 11 | carbonia
# Processing Record 28 of Set 11 | shimoda
# Processing Record 29 of Set 11 | makarov
# Processing Record 30 of Set 11 | green river
# Processing Record 31 of Set 11 | santa isabel
# Processing Record 32 of Set 11 | arrifes
# Processing Record 33 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 11 | lebyazhye
# Processing Record 35 of Set 11 | bubaque
# Processing Record 36 of Set 11 | ust-maya
# Processing Record 37 of Set 11 | virginia beach
# Processing Record 38 of Set 11 | kostomuksha
# Processing Record 39 of Set 11 | zyryanka
# Processing Record 40 of Set 11 | manitouwadge
# Processing Record 41 of Set 11 | nyaunglebin
# Processing Record 42 of Set 11 | augustow
# Processing Record 43 of Set 11 | tura
# Processing Record 44 of Set 11 | ivangorod
# Processing Record 45 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 11 | weihai
# Processing Record 47 of Set 11 | la palma
# Processing Record 48 of Set 11 | port moresby
# Processing Record 49 of Set 11 | ballina
# Processing Record 50 of Set 11 | dukat
# Processing Record 1 of Set 12 | maxixe
# Processing Record 2 of Set 12 | pangkalanbuun
# Processing Record 3 of Set 12 | bressuire
# Processing Record 4 of Set 12 | clarence town
# Processing Record 5 of Set 12 | yar-sale
# Processing Record 6 of Set 12 | kawalu
# Processing Record 7 of Set 12 | vestmannaeyjar
# Processing Record 8 of Set 12 | udachnyy
# Processing Record 9 of Set 12 | mahebourg
# Processing Record 10 of Set 12 | fougamou
# Processing Record 11 of Set 12 | surcin
# Processing Record 12 of Set 12 | manzhouli
# Processing Record 13 of Set 12 | san juan
# Processing Record 14 of Set 12 | kollam
# Processing Record 15 of Set 12 | nabire
# Processing Record 16 of Set 12 | synya
# Processing Record 17 of Set 12 | khairagarh
# Processing Record 18 of Set 12 | kichmengskiy gorodok
# Processing Record 19 of Set 12 | coos bay
# Processing Record 20 of Set 12 | saint anthony
# Processing Record 21 of Set 12 | jacareacanga
# Processing Record 22 of Set 12 | nouakchott
# Processing Record 23 of Set 12 | tocache
# Processing Record 24 of Set 12 | humberto de campos
# Processing Record 25 of Set 12 | freetown
# Processing Record 26 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 27 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 12 | saint-joseph
# Processing Record 29 of Set 12 | palu
# Processing Record 30 of Set 12 | bandar
# Processing Record 31 of Set 12 | ereymentau
# Processing Record 32 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 33 of Set 12 | rodos
# Processing Record 34 of Set 12 | hokitika
# Processing Record 35 of Set 12 | krasnoarmeysk
# Processing Record 36 of Set 12 | haapu
# City not found. Skipping...
# Processing Record 37 of Set 12 | ono
# Processing Record 38 of Set 12 | namatanai
# Processing Record 39 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 12 | akyab
# Processing Record 41 of Set 12 | ambulu
# Processing Record 42 of Set 12 | barcelos
# Processing Record 43 of Set 12 | maniitsoq
# Processing Record 44 of Set 12 | kargasok
# Processing Record 45 of Set 12 | san rafael
# Processing Record 46 of Set 12 | port augusta
# Processing Record 47 of Set 12 | belmonte
# Processing Record 48 of Set 12 | phan thiet
# Processing Record 49 of Set 12 | takab
# Processing Record 50 of Set 12 | abu zabad
# Processing Record 1 of Set 13 | abnub
# Processing Record 2 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 13 | severomuysk
# Processing Record 4 of Set 13 | tautira
# Processing Record 5 of Set 13 | teya
# Processing Record 6 of Set 13 | kamaishi
# Processing Record 7 of Set 13 | mbigou
# Processing Record 8 of Set 13 | ratnagiri
# Processing Record 9 of Set 13 | maun
# Processing Record 10 of Set 13 | isabela
# Processing Record 11 of Set 13 | songjianghe
# Processing Record 12 of Set 13 | brae
# Processing Record 13 of Set 13 | conde
# Processing Record 14 of Set 13 | srednekolymsk
# Processing Record 15 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 13 | klaksvik
# Processing Record 17 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 13 | gander
# Processing Record 19 of Set 13 | bella vista
# Processing Record 20 of Set 13 | mikuni
# Processing Record 21 of Set 13 | presidente medici
# Processing Record 22 of Set 13 | pleshanovo
# Processing Record 23 of Set 13 | rock sound
# Processing Record 24 of Set 13 | matara
# Processing Record 25 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 13 | fuyang
# Processing Record 27 of Set 13 | tawang
# Processing Record 28 of Set 13 | zholymbet
# Processing Record 29 of Set 13 | nikel
# Processing Record 30 of Set 13 | ostuni
# Processing Record 31 of Set 13 | ler
# Processing Record 32 of Set 13 | mancio lima
# Processing Record 33 of Set 13 | gusau
# Processing Record 34 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 35 of Set 13 | arman
# Processing Record 36 of Set 13 | lufilufi
# Processing Record 37 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 13 | kudahuvadhoo
# Processing Record 39 of Set 13 | san policarpo
# Processing Record 40 of Set 13 | jurm
# Processing Record 41 of Set 13 | uruzgan
# Processing Record 42 of Set 13 | do gonbadan
# Processing Record 43 of Set 13 | krasnoborsk
# Processing Record 44 of Set 13 | bechem
# Processing Record 45 of Set 13 | kang
# Processing Record 46 of Set 13 | loiza
# Processing Record 47 of Set 13 | yafran
# Processing Record 48 of Set 13 | roald
# Processing Record 49 of Set 13 | lazaro cardenas
# Processing Record 50 of Set 13 | kirovskiy
# Processing Record 1 of Set 14 | asyut
# Processing Record 2 of Set 14 | claye-souilly
# Processing Record 3 of Set 14 | kalmunai
# Processing Record 4 of Set 14 | champerico
# Processing Record 5 of Set 14 | ayios loukas
# City not found. Skipping...
# Processing Record 6 of Set 14 | marsaxlokk
# Processing Record 7 of Set 14 | volnovakha
# Processing Record 8 of Set 14 | marawi
# Processing Record 9 of Set 14 | howard springs
# Processing Record 10 of Set 14 | akdepe
# Processing Record 11 of Set 14 | frutigen
# Processing Record 12 of Set 14 | kuito
# Processing Record 13 of Set 14 | rosarito
# Processing Record 14 of Set 14 | gamba
# Processing Record 15 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 14 | puerto carreno
# Processing Record 17 of Set 14 | tabas
# Processing Record 18 of Set 14 | yenagoa
# Processing Record 19 of Set 14 | northam
# Processing Record 20 of Set 14 | pleasanton
# Processing Record 21 of Set 14 | khasan
# Processing Record 22 of Set 14 | avera
# Processing Record 23 of Set 14 | bavly
# Processing Record 24 of Set 14 | flagstaff
# Processing Record 25 of Set 14 | ivnya
# Processing Record 26 of Set 14 | yelizovo
# Processing Record 27 of Set 14 | torrington
# Processing Record 28 of Set 14 | jiwani
# Processing Record 29 of Set 14 | ayan
# Processing Record 30 of Set 14 | puebloviejo
# Processing Record 31 of Set 14 | hovd
# Processing Record 32 of Set 14 | bilma
# Processing Record 33 of Set 14 | fukue
# Processing Record 34 of Set 14 | sawakin
# Processing Record 35 of Set 14 | ahipara
# Processing Record 36 of Set 14 | pingliang
# Processing Record 37 of Set 14 | macusani
# Processing Record 38 of Set 14 | shestakovo
# Processing Record 39 of Set 14 | god
# Processing Record 40 of Set 14 | bemidji
# Processing Record 41 of Set 14 | komsomolskiy
# Processing Record 42 of Set 14 | bonfim
# Processing Record 43 of Set 14 | praya
# Processing Record 44 of Set 14 | oistins
# Processing Record 45 of Set 14 | aleksandrov gay
# Processing Record 46 of Set 14 | chornoliztsi
# Processing Record 47 of Set 14 | ponta pora
# Processing Record 48 of Set 14 | nyurba
# Processing Record 49 of Set 14 | bukama
# Processing Record 50 of Set 14 | nisia floresta
# Processing Record 1 of Set 15 | rincon
# Processing Record 2 of Set 15 | khapa
# Processing Record 3 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 15 | atar
# Processing Record 5 of Set 15 | upata
# Processing Record 6 of Set 15 | sibolga
# Processing Record 7 of Set 15 | odweyne
# Processing Record 8 of Set 15 | dniprorudne
# Processing Record 9 of Set 15 | asau
# Processing Record 10 of Set 15 | mesetas
# Processing Record 11 of Set 15 | fujinomiya
# Processing Record 12 of Set 15 | shenjiamen
# Processing Record 13 of Set 15 | zonguldak
# Processing Record 14 of Set 15 | arkhipo-osipovka
# Processing Record 15 of Set 15 | singapore
# Processing Record 16 of Set 15 | varna
# Processing Record 17 of Set 15 | manavalakurichi
# Processing Record 18 of Set 15 | paragominas
# Processing Record 19 of Set 15 | abu samrah
# Processing Record 20 of Set 15 | mount gambier
# Processing Record 21 of Set 15 | flin flon
# Processing Record 22 of Set 15 | mbabane
# Processing Record 23 of Set 15 | corpus christi
# Processing Record 24 of Set 15 | upington
# Processing Record 25 of Set 15 | ngaoundere
# Processing Record 26 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 27 of Set 15 | bella union
# Processing Record 28 of Set 15 | suoyarvi
# Processing Record 29 of Set 15 | grand gaube
# Processing Record 30 of Set 15 | mao
# Processing Record 31 of Set 15 | misratah
# Processing Record 32 of Set 15 | gumdag
# Processing Record 33 of Set 15 | baruun-urt
# Processing Record 34 of Set 15 | malpe
# Processing Record 35 of Set 15 | simbahan
# Processing Record 36 of Set 15 | kununurra
# Processing Record 37 of Set 15 | koprivnica
# Processing Record 38 of Set 15 | harper
# Processing Record 39 of Set 15 | eirunepe
# Processing Record 40 of Set 15 | tucuman
# Processing Record 41 of Set 15 | ucluelet
# Processing Record 42 of Set 15 | hofn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     63.48        60          86
# 1    Bredasdorp -34.5322   20.0403     66.54        87         100
# 2     Esperance -33.8667  121.9000     59.36        63          71
# 3       Aklavik  68.2191 -135.0107     -7.60        77          75
# 4     Busselton -33.6500  115.3333     51.13        80           0
# 5    Chokurdakh  70.6333  147.9167    -17.10        97         100
# 6          Lebu -37.6167  -73.6500     62.64        70           0
# 7      Hermanus -34.4187   19.2345     67.80        86         100
# 8  Krasnoselkup  65.7000   82.4667    -32.89       100          15
# 9         Kapaa  22.0752 -159.3190     82.72        66          75
#
#    Wind Speed Country Current Description
# 0        2.04      NZ     overcast clouds
# 1       16.08      ZA     overcast clouds
# 2       12.97      AU       broken clouds
# 3        4.61      CA       broken clouds
# 4        9.10      AU           clear sky
# 5       11.48      RU     overcast clouds
# 6       14.14      CL           clear sky
# 7       19.46      ZA     overcast clouds
# 8        3.65      RU          few clouds
# 9       16.11      US       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]



# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     63.48        60          86
# 1    Bredasdorp      ZA -34.5322   20.0403     66.54        87         100
# 2     Esperance      AU -33.8667  121.9000     59.36        63          71
# 3       Aklavik      CA  68.2191 -135.0107     -7.60        77          75
# 4     Busselton      AU -33.6500  115.3333     51.13        80           0
# 5    Chokurdakh      RU  70.6333  147.9167    -17.10        97         100
# 6          Lebu      CL -37.6167  -73.6500     62.64        70           0
# 7      Hermanus      ZA -34.4187   19.2345     67.80        86         100
# 8  Krasnoselkup      RU  65.7000   82.4667    -32.89       100          15
# 9         Kapaa      US  22.0752 -159.3190     82.72        66          75
#
#    Wind Speed Current Description
# 0        2.04     overcast clouds
# 1       16.08     overcast clouds
# 2       12.97       broken clouds
# 3        4.61       broken clouds
# 4        9.10           clear sky
# 5       11.48     overcast clouds
# 6       14.14           clear sky
# 7       19.46     overcast clouds
# 8        3.65          few clouds
# 9       16.11       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_DataBase/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24520\3233558035.py in <module>
#       3
#       4 # Export the city_data DataFrame into a CSV file
# ----> 5 city_data_df.to_csv(output_data_file, index_label="City")
#
# c:\Users\Bryce\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# c:\Users\Bryce\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# c:\Users\Bryce\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# c:\Users\Bryce\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_DataBase/WeatherPy_Database.csv'
